# %%
import time
import torch
from torch.utils.data import DataLoader, Dataset
import PIL
import os

from torchvision import transforms as transforms
import torch.optim as optim
from torchvision import models
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix
import pickle
import torch.nn.functional as F
import seaborn as sns
import sys
sys.path.append('../')
from utils import MHCoverDataset, get_dataloader
from pathlib import Path
from utils.training import TrainingInterface

# %%
train_df = pd.read_csv("../data/train_o.csv")
test_df = pd.read_csv("../data/test.csv")
val_df = pd.read_csv("../data/val.csv")

# %%
my_train_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.RandomHorizontalFlip(p=0.3),
        transforms.RandomRotation(degrees=45),
        transforms.RandomVerticalFlip(p=0.3),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.RandomGrayscale(p=0.2),
        transforms.RandomPerspective(p=0.2),
        transforms.RandomEqualize(p=0.2),
        transforms.RandomAutocontrast(p=0.2),
        transforms.ToTensor(),
    ]
)

# %%
my_test_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.ToTensor(),
    ]
)

# %%
def trainloader():
    trainloader = get_dataloader(
        root_dir="../data/train1/",
        df=train_df,
        fp_label_translator='../utils/dataset/label_translate.pkl',
        transformations=my_train_transforms,
        batch_size=32,
        workers=0,
        pin_memory=True,
        shuffle=True
    )
    return trainloader

def valloader():
    valloader = get_dataloader(
        root_dir="../data/val1/",
        df=val_df,
        fp_label_translator='../utils/dataset/label_translate.pkl',
        transformations=my_train_transforms,
        batch_size=32,
        workers=0,
        pin_memory=True,
        shuffle=True
    )
    return valloader

testloader = get_dataloader(
    root_dir="../data/test1/",
    df=pd.read_csv("../data/test.csv"),
    fp_label_translator='../utils/dataset/label_translate.pkl',
    transformations=my_test_transforms,
    batch_size=32,
    workers=0,
    pin_memory=True,
    shuffle=True
)

# %%
# Visualize one training batch
for images, labels in valloader():
    fig, ax = plt.subplots(figsize = (10, 10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(images, 4).permute(1,2,0))
    break

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Networks

# %%
resnet18 = models.resnet18(pretrained=False, progress=True)
resnet18 = TrainingInterface(model=resnet18, name="resnet18")

# %% [markdown]
# ## Functions

# %%
def train(model, iterator, optimizer, criterion, device, regularizer = None):
    
    epoch_loss = 0
    epoch_acc = 0
    model.train()
    
    for (x, y) in iterator:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()    
        y_pred = model(x)
        loss = criterion(y_pred, y)
        
        if regularizer == "L1":
            l1_l_c = nn.L1Loss()
            l1_lambda = 0.01
            l1_norm = 0
            for parameter in model.parameters():
                l1_norm += l1_l_c(parameter,target=torch.zeros_like(parameter))
            l1 = l1_lambda * l1_norm
            # Add L1 loss component
            loss += l1
        
        acc = calculate_accuracy(y_pred, y)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device, regularizer = None):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            y_pred = model(x)

            loss = criterion(y_pred, y)
            if regularizer == "L1":
                l1_l_c = nn.L1Loss()
                l1_lambda = 0.01
                l1_norm = 0
                for parameter in model.parameters():
                    l1_norm += l1_l_c(parameter,target=torch.zeros_like(parameter))
                l1 = l1_lambda * l1_norm
                # Add L1 loss component
                loss += l1

            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def epoch_time(start, end):
    elapsed_time = end - start
    elapsed_in_min = int(elapsed_time / 60)
    elapsed_in_sec = int(elapsed_time - (elapsed_in_min * 60))
    return elapsed_in_min, elapsed_in_sec

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    accuracy = correct.float() / y.shape[0]
    return accuracy

# %%
def train_epoch(epochs, model, trainloader,valloader, optimizer, criterion, device, regularizer = None):
   
    train_losses = []
    train_accuracy = []
    valid_losses = []
    valid_accuracy = []
    best_valid_loss = float('inf')
    for epoch in range(epochs):
        
        start_time = time.monotonic()

        train_loss, train_acc = train(model, trainloader, optimizer, criterion, device, regularizer = regularizer)
        valid_loss, valid_acc = evaluate(model, valloader, criterion, device, regularizer = regularizer)

        end_time = time.monotonic()

        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        train_losses.append(train_loss)
        train_accuracy.append(train_acc)
        valid_losses.append(valid_loss)
        valid_accuracy.append(valid_acc)
        
        print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s || Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% || Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
    return model, train_losses, train_accuracy, valid_losses, valid_accuracy

# %%
def metric_evaluation(y_test, y_pred):
    conf_mat = confusion_matrix(y_true=y_test, y_pred=y_pred)
    
    fig = plt.subplots(figsize=(20, 5))
    plt.subplot(1,2,1)
    p1 = sns.heatmap(conf_mat, annot=True, fmt='d',xticklabels=classes,yticklabels=classes, cmap="YlGnBu")
    p1.set_title('Confusion Matrix')
    p1.set_ylabel('True')
    p1.set_xlabel('Predicted')

    plt.subplot(1,2,2)
    recall = recall_score(y_test, y_pred, average='macro', zero_division=0)
    precision = precision_score(y_test, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)
    metric_names = ['Recall Macro', 'Precision Macro', 'F1 Macro']
    metrics = [recall, precision, f1]

    p2 = sns.barplot(x=metric_names, y=metrics,palette="Blues_d")
    for i, value in enumerate(metrics):
        plt.text(x=i, y=value, s=str(round(value,3)), ha='center')
    p2.set_ylim(0,1) 
    p2.set_title('metrics')
    p2.set_ylabel('Score')
    sns.despine()

    plt.show()

# %%
def get_predictions(model, iterator, device):
    
    model.eval()
    images = []
    labels = []
    probs = []
    
    with torch.no_grad():
        for (x, y) in iterator:
            x = x.to(device)
            y_pred = model(x)
            
            y_prob = F.softmax(y_pred, dim = -1)
            top_pred = y_prob.argmax(1, keepdim = True)

            images.append(x.cpu())
            labels.append(y.cpu())
            probs.append(y_prob.cpu())

    images = torch.cat(images, dim = 0)
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return images, labels, probs

# %%
def loss_acc_function(train_loss,valid_loss,train_acc,valid_acc):
    
    fig = plt.subplots(figsize=(15, 5))
    plt.subplot(1,2,1)
    plt.plot(train_loss, label='Training loss')
    plt.plot(valid_loss, label='Validation loss')
    plt.title('Training and Validation loss')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(frameon=False)
    
    plt.subplot(1,2,2)
    plt.plot(train_acc, label='Training accuracy')
    plt.plot(valid_acc, label='Validation accuracy')
    plt.title('Training and Validation accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend(frameon=False)
    plt.show()

# %% [markdown]
# ## Resnet18
#
# - optimizer = SGD
# - Regularisierung = Keine
# - ohne argumentation

# %%
batch_size = 32
epochs = 200
num_workers = 0
learning_rate = 0.005

# %%
model = resnet18.model
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
model, train_losses, train_accuracy, valid_losses, valid_accuracy = train_epoch(epochs, model, trainloader(),valloader(), optimizer, criterion, device)
# Out:
# Epoch: 01 | Epoch Time: 0m 14s || Train Loss: 2.287 | Train Acc: 41.01% || Val. Loss: 1.986 |  Val. Acc: 38.39%
# Epoch: 02 | Epoch Time: 0m 15s || Train Loss: 1.278 | Train Acc: 58.54% || Val. Loss: 1.387 |  Val. Acc: 54.46%
# Epoch: 03 | Epoch Time: 0m 14s || Train Loss: 1.004 | Train Acc: 71.70% || Val. Loss: 1.020 |  Val. Acc: 74.11%
# Epoch: 04 | Epoch Time: 0m 23s || Train Loss: 0.883 | Train Acc: 74.27% || Val. Loss: 1.890 |  Val. Acc: 46.88%
# Epoch: 05 | Epoch Time: 0m 14s || Train Loss: 0.769 | Train Acc: 77.86% || Val. Loss: 1.286 |  Val. Acc: 59.82%
# Epoch: 06 | Epoch Time: 0m 14s || Train Loss: 0.700 | Train Acc: 79.03% || Val. Loss: 1.169 |  Val. Acc: 68.30%
# Epoch: 07 | Epoch Time: 0m 19s || Train Loss: 0.643 | Train Acc: 81.97% || Val. Loss: 1.533 |  Val. Acc: 61.61%
# Epoch: 08 | Epoch Time: 0m 15s || Train Loss: 0.564 | Train Acc: 82.35% || Val. Loss: 1.439 |  Val. Acc: 66.52%
# Epoch: 09 | Epoch Time: 0m 14s || Train Loss: 0.457 | Train Acc: 85.32% || Val. Loss: 1.054 |  Val. Acc: 71.88%
# Epoch: 10 | Epoch Time: 0m 14s || Train Loss: 0.393 | Train Acc: 87.59% || Val. Loss: 1.051 |  Val. Acc: 75.00%
# Epoch: 11 | Epoch Time: 0m 14s || Train Loss: 0.280 | Train Acc: 91.14% || Val. Loss: 1.158 |  Val. Acc: 70.54%
# Epoch: 12 | Epoch Time: 0m 14s || Train Loss: 0.249 | Train Acc: 92.84% || Val. Loss: 1.370 |  Val. Acc: 63.84%
# Epoch: 13 | Epoch Time: 0m 14s || Train Loss: 0.210 | Train Acc: 93.73% || Val. Loss: 1.617 |  Val. Acc: 50.00%
# Epoch: 14 | Epoch Time: 0m 14s || Train Loss: 0.179 | Train Acc: 94.60% || Val. Loss: 2.067 |  Val. Acc: 42.41%
| Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.652 |  Val. Acc: 79.02%
# Epoch: 189 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.602 |  Val. Acc: 79.02%
# Epoch: 190 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.523 |  Val. Acc: 80.80%
# Epoch: 191 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.476 |  Val. Acc: 80.80%
# Epoch: 192 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.617 |  Val. Acc: 79.46%
# Epoch: 193 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.487 |  Val. Acc: 81.70%
# Epoch: 194 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.540 |  Val. Acc: 81.25%
# Epoch: 195 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.601 |  Val. Acc: 80.36%
# Epoch: 196 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.567 |  Val. Acc: 79.91%
# Epoch: 197 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.419 |  Val. Acc: 81.25%
# Epoch: 198 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.446 |  Val. Acc: 80.36%
# Epoch: 199 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.444 |  Val. Acc: 80.80%
# Epoch: 200 | Epoch Time: 0m 15s || Train Loss: 0.000 | Train Acc: 100.00% || Val. Loss: 1.463 |  Val. Acc: 80.80%

# %%
loss_acc_function(train_losses,valid_losses,train_accuracy,valid_accuracy)

# %%
test_loss, test_acc = evaluate(model, testloader, criterion, device)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.864 | Test Acc: 86.01%

# %%
images, labels, probs = get_predictions(model, testloader, device)
pred_labels = torch.argmax(probs, 1)
f1_SGD_32ba_20ep_001lr = f1_score(labels, pred_labels, average='macro', zero_division=0)

# %%
with open('../utils/dataset/label_translate.pkl', 'rb') as pkl_file:
    label_dict = pickle.load(pkl_file)

# %%
classes = list(label_dict)

# %%
metric_evaluation(labels, pred_labels)

# %% [markdown]
# ## Resnet18
#
# - optimizer = SGD
# - Regularisierung = Keine
# - mit argumentation

# %%
batch_size = 32
epochs = 200
num_workers = 0
learning_rate = 0.005

# %%
model = resnet18.model
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
model, train_losses, train_accuracy, valid_losses, valid_accuracy = train_epoch(epochs, model, trainloader(),valloader(), optimizer, criterion, device)
# Out:
# Epoch: 01 | Epoch Time: 0m 26s || Train Loss: 2.709 | Train Acc: 30.36% || Val. Loss: 2.938 |  Val. Acc: 30.36%
# Epoch: 02 | Epoch Time: 0m 22s || Train Loss: 1.768 | Train Acc: 41.37% || Val. Loss: 1.691 |  Val. Acc: 44.20%
# Epoch: 03 | Epoch Time: 0m 22s || Train Loss: 1.647 | Train Acc: 44.20% || Val. Loss: 2.048 |  Val. Acc: 41.96%
# Epoch: 04 | Epoch Time: 0m 22s || Train Loss: 1.575 | Train Acc: 47.00% || Val. Loss: 2.394 |  Val. Acc: 24.55%
# Epoch: 05 | Epoch Time: 0m 22s || Train Loss: 1.424 | Train Acc: 54.22% || Val. Loss: 1.910 |  Val. Acc: 42.41%
# Epoch: 06 | Epoch Time: 0m 22s || Train Loss: 1.368 | Train Acc: 56.14% || Val. Loss: 1.556 |  Val. Acc: 44.20%
# Epoch: 07 | Epoch Time: 0m 23s || Train Loss: 1.212 | Train Acc: 61.06% || Val. Loss: 2.935 |  Val. Acc: 31.25%
# Epoch: 08 | Epoch Time: 0m 22s || Train Loss: 1.186 | Train Acc: 63.93% || Val. Loss: 2.372 |  Val. Acc: 39.73%
# Epoch: 190 | Epoch Time: 0m 24s || Train Loss: 0.247 | Train Acc: 92.44% || Val. Loss: 0.945 |  Val. Acc: 82.14%
# Epoch: 191 | Epoch Time: 0m 24s || Train Loss: 0.246 | Train Acc: 92.78% || Val. Loss: 1.305 |  Val. Acc: 76.79%
# Epoch: 192 | Epoch Time: 0m 24s || Train Loss: 0.270 | Train Acc: 91.38% || Val. Loss: 0.869 |  Val. Acc: 83.48%
# Epoch: 193 | Epoch Time: 0m 24s || Train Loss: 0.246 | Train Acc: 92.49% || Val. Loss: 0.999 |  Val. Acc: 80.36%
# Epoch: 194 | Epoch Time: 0m 24s || Train Loss: 0.240 | Train Acc: 92.82% || Val. Loss: 1.143 |  Val. Acc: 78.57%
# Epoch: 195 | Epoch Time: 0m 24s || Train Loss: 0.256 | Train Acc: 91.63% || Val. Loss: 1.147 |  Val. Acc: 75.45%
# Epoch: 196 | Epoch Time: 0m 24s || Train Loss: 0.243 | Train Acc: 92.69% || Val. Loss: 1.101 |  Val. Acc: 79.02%
# Epoch: 197 | Epoch Time: 0m 24s || Train Loss: 0.242 | Train Acc: 91.86% || Val. Loss: 0.945 |  Val. Acc: 78.57%
# Epoch: 198 | Epoch Time: 0m 24s || Train Loss: 0.205 | Train Acc: 93.10% || Val. Loss: 1.017 |  Val. Acc: 81.70%
# Epoch: 199 | Epoch Time: 0m 24s || Train Loss: 0.248 | Train Acc: 92.31% || Val. Loss: 1.033 |  Val. Acc: 81.70%
# Epoch: 200 | Epoch Time: 0m 24s || Train Loss: 0.241 | Train Acc: 92.18% || Val. Loss: 1.052 |  Val. Acc: 78.57%

# %%
loss_acc_function(train_losses,valid_losses,train_accuracy,valid_accuracy)

# %%
test_loss, test_acc = evaluate(model, testloader, criterion, device)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.697 | Test Acc: 87.15%

# %%
images, labels, probs = get_predictions(model, testloader, device)
pred_labels = torch.argmax(probs, 1)
f1_SGD_32ba_20ep_001lr = f1_score(labels, pred_labels, average='macro', zero_division=0)

# %%
with open('../utils/dataset/label_translate.pkl', 'rb') as pkl_file:
    label_dict = pickle.load(pkl_file)

# %%
classes = list(label_dict)

# %%
metric_evaluation(labels, pred_labels)

# %% [markdown]
# ## Resnet18
#
# - optimizer = SGD
# - Regularisierung = ja 0.0001
# - mit argumentation

# %%
batch_size = 32
epochs = 200
num_workers = 0
learning_rate = 0.005

# %%
model = resnet18.model
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9,weight_decay=0.0001)

# %%
model, train_losses, train_accuracy, valid_losses, valid_accuracy = train_epoch(epochs, model, trainloader(),valloader(), optimizer, criterion, device)
# Out:
# Epoch: 01 | Epoch Time: 0m 26s || Train Loss: 2.702 | Train Acc: 31.13% || Val. Loss: 3.389 |  Val. Acc: 31.25%
# Epoch: 02 | Epoch Time: 0m 22s || Train Loss: 1.714 | Train Acc: 41.09% || Val. Loss: 1.998 |  Val. Acc: 31.70%
# Epoch: 03 | Epoch Time: 0m 22s || Train Loss: 1.717 | Train Acc: 42.56% || Val. Loss: 1.981 |  Val. Acc: 38.39%
# Epoch: 185 | Epoch Time: 0m 25s || Train Loss: 0.265 | Train Acc: 91.92% || Val. Loss: 1.065 |  Val. Acc: 81.25%
# Epoch: 186 | Epoch Time: 0m 25s || Train Loss: 0.228 | Train Acc: 92.77% || Val. Loss: 1.167 |  Val. Acc: 80.80%
# Epoch: 187 | Epoch Time: 0m 25s || Train Loss: 0.227 | Train Acc: 93.17% || Val. Loss: 1.017 |  Val. Acc: 78.12%
# Epoch: 188 | Epoch Time: 0m 25s || Train Loss: 0.232 | Train Acc: 92.33% || Val. Loss: 1.264 |  Val. Acc: 74.11%
# Epoch: 189 | Epoch Time: 0m 25s || Train Loss: 0.249 | Train Acc: 91.80% || Val. Loss: 0.979 |  Val. Acc: 79.02%
# Epoch: 190 | Epoch Time: 0m 25s || Train Loss: 0.252 | Train Acc: 92.19% || Val. Loss: 0.971 |  Val. Acc: 80.36%
# Epoch: 191 | Epoch Time: 0m 25s || Train Loss: 0.236 | Train Acc: 92.48% || Val. Loss: 1.278 |  Val. Acc: 76.79%
# Epoch: 192 | Epoch Time: 0m 25s || Train Loss: 0.226 | Train Acc: 93.01% || Val. Loss: 1.154 |  Val. Acc: 75.00%
# Epoch: 193 | Epoch Time: 0m 25s || Train Loss: 0.238 | Train Acc: 93.00% || Val. Loss: 0.971 |  Val. Acc: 79.91%
# Epoch: 194 | Epoch Time: 0m 25s || Train Loss: 0.197 | Train Acc: 93.74% || Val. Loss: 0.999 |  Val. Acc: 80.36%
# Epoch: 195 | Epoch Time: 0m 25s || Train Loss: 0.243 | Train Acc: 91.96% || Val. Loss: 1.087 |  Val. Acc: 78.57%
# Epoch: 196 | Epoch Time: 0m 25s || Train Loss: 0.251 | Train Acc: 92.02% || Val. Loss: 1.063 |  Val. Acc: 78.12%
# Epoch: 197 | Epoch Time: 0m 25s || Train Loss: 0.198 | Train Acc: 93.67% || Val. Loss: 1.086 |  Val. Acc: 81.25%
# Epoch: 198 | Epoch Time: 0m 25s || Train Loss: 0.222 | Train Acc: 92.83% || Val. Loss: 1.101 |  Val. Acc: 77.23%
# Epoch: 199 | Epoch Time: 0m 25s || Train Loss: 0.229 | Train Acc: 92.49% || Val. Loss: 1.052 |  Val. Acc: 79.46%
# Epoch: 200 | Epoch Time: 0m 25s || Train Loss: 0.215 | Train Acc: 93.21% || Val. Loss: 0.986 |  Val. Acc: 81.70%

# %%
loss_acc_function(train_losses,valid_losses,train_accuracy,valid_accuracy)

# %%
test_loss, test_acc = evaluate(model, testloader, criterion, device)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.831 | Test Acc: 86.36%

# %%
images, labels, probs = get_predictions(model, testloader, device)
pred_labels = torch.argmax(probs, 1)
f1_SGD_32ba_20ep_001lr = f1_score(labels, pred_labels, average='macro', zero_division=0)

# %%
with open('../utils/dataset/label_translate.pkl', 'rb') as pkl_file:
    label_dict = pickle.load(pkl_file)

# %%
classes = list(label_dict)

# %%
metric_evaluation(labels, pred_labels)
