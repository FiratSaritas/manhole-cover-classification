# %%
import time
import torch
from torch.utils.data import DataLoader, Dataset
import PIL
import os

from torchvision import transforms as transforms
import torch.optim as optim
from torchvision import models
import torch.nn as nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix
import pickle
import torch.nn.functional as F
import seaborn as sns
import sys
sys.path.append('../')
from utils import MHCoverDataset, get_dataloader
from pathlib import Path
from utils.training import TrainingInterface
from utils.plots import EvaluationPlots

# %%
my_train_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.RandomHorizontalFlip(p=0.3),
        transforms.RandomRotation(degrees=45),
        transforms.RandomVerticalFlip(p=0.3),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.RandomGrayscale(p=0.2),
        transforms.RandomPerspective(p=0.2),
        transforms.RandomEqualize(p=0.2),
        transforms.RandomAutocontrast(p=0.2),
        transforms.ToTensor(),
    ]
)

my_test_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.ToTensor(),
    ]
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
df = pd.read_csv("../data/labels_without_others.csv")

# %%
df.rename(columns={"label":"sub"},inplace=True)
df.rename(columns={"sublabel":"label"},inplace=True)

# %% [markdown]
# ### Networks

# %%
resnet101 = models.resnet101(pretrained=False, progress=True)
resnet101 = TrainingInterface(model=resnet101, name="resnet101")

# %%
n_epochs = 200
learning_rate = 0.005

# %%
model = resnet101.model
model = model.to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9,weight_decay=0.0001)

# %% [markdown]
# ## Typ predicion

# %%
sns.countplot(x="label",data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
pkl_url_file = "../utils/dataset/label_new.pkl"
root_dir = "../data/images_transformed/"

# %%
with open(pkl_url_file, 'rb') as pkl_file:
    label_dict = pickle.load(pkl_file)

# %%
trainloader = get_dataloader(
    root_dir=root_dir,
    df=df[df.set =="train"],
    fp_label_translator=pkl_url_file,
    transformations=my_train_transforms,
    batch_size=32,
    workers=0,
    pin_memory=True,
    shuffle=True
)



valloader = get_dataloader(
    root_dir=root_dir,
    df=df[df.set =="val"],
    fp_label_translator=pkl_url_file,
    transformations=my_train_transforms,
    batch_size=32,
    workers=0,
    pin_memory=True,
    shuffle=True
)


testloader = get_dataloader(
    root_dir=root_dir,
    df=df[df.set =="test"],
    fp_label_translator=pkl_url_file,
    transformations=my_test_transforms,
    batch_size=32,
    workers=0,
    pin_memory=True,
    shuffle=False
)

# %%
# Visualize one training batch
for images, labels in trainloader:
    fig, ax = plt.subplots(figsize = (10, 10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(images, 4).permute(1,2,0))
    break

# %% [markdown]
# ### Train

# %%
resnet101.train(criterion = criterion, optimizer = optimizer, n_epochs = n_epochs, dataloader_train = trainloader ,dataloader_val= valloader)
# Out:
#   0%|          | 0/10600 [00:00<?, ?it/s]
# Epoch 1/200: [Train-Loss = 176.062] || [Validation-Loss = 33.163]
# Epoch 2/200: [Train-Loss = 112.714] || [Validation-Loss = 12.204]
# Epoch 3/200: [Train-Loss = 100.765] || [Validation-Loss = 11.638]
# Epoch 4/200: [Train-Loss = 92.382] || [Validation-Loss = 11.199]
# Epoch 5/200: [Train-Loss = 91.833] || [Validation-Loss = 12.917]
# Epoch 6/200: [Train-Loss = 91.627] || [Validation-Loss = 10.497]
# Epoch 7/200: [Train-Loss = 85.759] || [Validation-Loss = 11.062]
# Epoch 8/200: [Train-Loss = 82.535] || [Validation-Loss = 10.557]
# Epoch 9/200: [Train-Loss = 84.195] || [Validation-Loss = 9.83]
# Epoch 10/200: [Train-Loss = 75.978] || [Validation-Loss = 10.463]
# Epoch 11/200: [Train-Loss = 77.278] || [Validation-Loss = 10.353]
# Epoch 12/200: [Train-Loss = 74.769] || [Validation-Loss = 10.539]
# Epoch 13/200: [Train-Loss = 71.654] || [Validation-Loss = 9.994]
# Epoch 14/200: [Train-Loss = 71.272] || [Validation-Loss = 9.492]
# Epoch 15/200: [Train-Loss = 68.497] || [Validation-Loss = 10.068]
# Epoch 16/200: [Train-Loss = 65.173] || [Validation-Loss = 9.771]
# Epoch 17/200: [Train-Loss = 65.819] || [Validation-Loss = 10.248]
# Epoch 18/200: [Train-Loss = 63.71] || [Validation-Loss = 8.497]
# Epoch 19/200: [Train-Loss = 60.18] || [Validation-Loss = 8.338]
# Epoch 20/200: [Train-Loss = 57.355] || [Validation-Loss = 7.034]
# Epoch 21/200: [Train-Loss = 53.718] || [Validation-Loss = 9.257]
# Epoch 22/200: [Train-Loss = 54.283] || [Validation-Loss = 11.43]
# Epoch 23/200: [Train-Loss = 53.065] || [Validation-Loss = 6.547]
# Epoch 24/200: [Train-Loss = 51.387] || [Validation-Loss = 7.263]
# Epoch 25/200: [Train-Loss = 50.366] || [Validation-Loss = 8.382]
# Epoch 26/200: [Train-Loss = 50.044] || [Validation-Loss = 7.908]
# Epoch 27/200: [Train-Loss = 48.533] || [Validation-Loss = 7.059]
# Epoch 28/200: [Train-Loss = 47.9] || [Validation-Loss = 7.077]
# Epoch 29/200: [Train-Loss = 48.504] || [Validation-Loss = 9.273]
# Epoch 30/200: [Train-Loss = 47.389] || [Validation-Loss = 6.881]
# Epoch 31/200: [Train-Loss = 48.818] || [Validation-Loss = 8.599]
# Epoch 32/200: [Train-Loss = 47.326] || [Validation-Loss = 6.253]
# Epoch 33/200: [Train-Loss = 47.058] || [Validation-Loss = 5.907]
# Epoch 34/200: [Train-Loss = 47.944] || [Validation-Loss = 5.547]
# Epoch 35/200: [Train-Loss = 41.173] || [Validation-Loss = 6.045]
# Epoch 36/200: [Train-Loss = 43.678] || [Validation-Loss = 6.544]
# Epoch 37/200: [Train-Loss = 39.657] || [Validation-Loss = 6.104]
# Epoch 38/200: [Train-Loss = 40.402] || [Validation-Loss = 6.685]
# Epoch 39/200: [Train-Loss = 39.976] || [Validation-Loss = 7.783]
# Epoch 40/200: [Train-Loss = 37.839] || [Validation-Loss = 5.791]
# Epoch 41/200: [Train-Loss = 38.631] || [Validation-Loss = 5.45]
# Epoch 42/200: [Train-Loss = 42.544] || [Validation-Loss = 6.561]
# Epoch 43/200: [Train-Loss = 39.174] || [Validation-Loss = 7.409]
# Epoch 44/200: [Train-Loss = 37.655] || [Validation-Loss = 6.018]
# Epoch 45/200: [Train-Loss = 36.359] || [Validation-Loss = 5.398]
# Epoch 46/200: [Train-Loss = 36.981] || [Validation-Loss = 6.747]
# Epoch 47/200: [Train-Loss = 39.453] || [Validation-Loss = 5.945]
# Epoch 48/200: [Train-Loss = 38.94] || [Validation-Loss = 5.799]
# Epoch 49/200: [Train-Loss = 37.361] || [Validation-Loss = 6.302]
# Epoch 50/200: [Train-Loss = 35.491] || [Validation-Loss = 5.938]
# Epoch 51/200: [Train-Loss = 35.18] || [Validation-Loss = 7.33]
# Epoch 52/200: [Train-Loss = 37.338] || [Validation-Loss = 11.456]
# Epoch 53/200: [Train-Loss = 36.401] || [Validation-Loss = 5.917]
# Epoch 54/200: [Train-Loss = 36.085] || [Validation-Loss = 6.873]
# Epoch 55/200: [Train-Loss = 40.407] || [Validation-Loss = 6.132]
# Epoch 56/200: [Train-Loss = 38.201] || [Validation-Loss = 6.42]
# Epoch 57/200: [Train-Loss = 33.857] || [Validation-Loss = 6.442]
# Epoch 58/200: [Train-Loss = 35.862] || [Validation-Loss = 5.896]
# Epoch 59/200: [Train-Loss = 37.641] || [Validation-Loss = 6.862]
# Epoch 60/200: [Train-Loss = 36.181] || [Validation-Loss = 6.356]
# Epoch 61/200: [Train-Loss = 35.441] || [Validation-Loss = 5.425]
# Epoch 62/200: [Train-Loss = 35.294] || [Validation-Loss = 5.738]
# Epoch 63/200: [Train-Loss = 34.72] || [Validation-Loss = 6.965]
# Epoch 64/200: [Train-Loss = 35.163] || [Validation-Loss = 4.998]
# Epoch 65/200: [Train-Loss = 33.422] || [Validation-Loss = 5.034]
# Epoch 66/200: [Train-Loss = 34.077] || [Validation-Loss = 5.809]
# Epoch 67/200: [Train-Loss = 32.018] || [Validation-Loss = 5.253]
# Epoch 68/200: [Train-Loss = 33.518] || [Validation-Loss = 5.445]
# Epoch 69/200: [Train-Loss = 33.086] || [Validation-Loss = 5.211]
# Epoch 70/200: [Train-Loss = 35.452] || [Validation-Loss = 5.83]
# Epoch 71/200: [Train-Loss = 35.597] || [Validation-Loss = 6.494]
# Epoch 72/200: [Train-Loss = 32.855] || [Validation-Loss = 6.19]
# Epoch 73/200: [Train-Loss = 30.503] || [Validation-Loss = 5.51]
# Epoch 74/200: [Train-Loss = 30.789] || [Validation-Loss = 4.924]
# Epoch 75/200: [Train-Loss = 32.375] || [Validation-Loss = 5.541]
# Epoch 76/200: [Train-Loss = 31.574] || [Validation-Loss = 4.85]
# Epoch 77/200: [Train-Loss = 31.462] || [Validation-Loss = 5.477]
# Epoch 78/200: [Train-Loss = 31.246] || [Validation-Loss = 7.981]
# Epoch 79/200: [Train-Loss = 30.962] || [Validation-Loss = 5.063]
# Epoch 80/200: [Train-Loss = 31.414] || [Validation-Loss = 4.547]
# Epoch 81/200: [Train-Loss = 32.251] || [Validation-Loss = 5.252]
# Epoch 82/200: [Train-Loss = 30.818] || [Validation-Loss = 7.085]
# Epoch 83/200: [Train-Loss = 29.555] || [Validation-Loss = 5.83]
# Epoch 84/200: [Train-Loss = 31.693] || [Validation-Loss = 4.998]
# Epoch 85/200: [Train-Loss = 31.9] || [Validation-Loss = 5.826]
# Epoch 86/200: [Train-Loss = 30.494] || [Validation-Loss = 11.766]
# Epoch 87/200: [Train-Loss = 33.479] || [Validation-Loss = 5.665]
# Epoch 88/200: [Train-Loss = 30.926] || [Validation-Loss = 6.332]
# Epoch 89/200: [Train-Loss = 30.845] || [Validation-Loss = 6.324]
# Epoch 90/200: [Train-Loss = 28.401] || [Validation-Loss = 6.874]
# Epoch 91/200: [Train-Loss = 29.928] || [Validation-Loss = 5.49]
# Epoch 92/200: [Train-Loss = 30.539] || [Validation-Loss = 5.821]
# Epoch 93/200: [Train-Loss = 29.503] || [Validation-Loss = 5.751]
# Epoch 94/200: [Train-Loss = 29.996] || [Validation-Loss = 6.229]
# Epoch 95/200: [Train-Loss = 29.541] || [Validation-Loss = 6.309]
# Epoch 96/200: [Train-Loss = 28.088] || [Validation-Loss = 5.746]
# Epoch 97/200: [Train-Loss = 28.999] || [Validation-Loss = 6.312]
# Epoch 98/200: [Train-Loss = 28.65] || [Validation-Loss = 6.652]
# Epoch 99/200: [Train-Loss = 28.492] || [Validation-Loss = 5.977]
# Epoch 100/200: [Train-Loss = 29.337] || [Validation-Loss = 6.636]
# Epoch 101/200: [Train-Loss = 30.664] || [Validation-Loss = 6.514]
# Epoch 102/200: [Train-Loss = 29.047] || [Validation-Loss = 6.099]
# Epoch 103/200: [Train-Loss = 29.693] || [Validation-Loss = 6.793]
# Epoch 104/200: [Train-Loss = 27.633] || [Validation-Loss = 5.017]
# Epoch 105/200: [Train-Loss = 27.764] || [Validation-Loss = 4.978]
# Epoch 106/200: [Train-Loss = 28.748] || [Validation-Loss = 7.112]
# Epoch 107/200: [Train-Loss = 30.569] || [Validation-Loss = 5.901]
# Epoch 108/200: [Train-Loss = 27.708] || [Validation-Loss = 5.986]
# Epoch 109/200: [Train-Loss = 26.737] || [Validation-Loss = 5.218]
# Epoch 110/200: [Train-Loss = 27.4] || [Validation-Loss = 5.541]
# Epoch 111/200: [Train-Loss = 29.093] || [Validation-Loss = 6.242]
# Epoch 112/200: [Train-Loss = 28.402] || [Validation-Loss = 9.259]
# Epoch 113/200: [Train-Loss = 28.044] || [Validation-Loss = 4.714]
# Epoch 114/200: [Train-Loss = 25.404] || [Validation-Loss = 5.205]
# Epoch 115/200: [Train-Loss = 27.068] || [Validation-Loss = 10.63]
# Epoch 116/200: [Train-Loss = 28.167] || [Validation-Loss = 5.947]
# Epoch 117/200: [Train-Loss = 27.897] || [Validation-Loss = 5.595]
# Epoch 118/200: [Train-Loss = 26.773] || [Validation-Loss = 5.437]
# Epoch 119/200: [Train-Loss = 27.2] || [Validation-Loss = 6.743]
# Epoch 120/200: [Train-Loss = 26.036] || [Validation-Loss = 6.657]
# Epoch 121/200: [Train-Loss = 26.872] || [Validation-Loss = 5.625]
# Epoch 122/200: [Train-Loss = 24.991] || [Validation-Loss = 6.714]
# Epoch 123/200: [Train-Loss = 26.848] || [Validation-Loss = 6.168]
# Epoch 124/200: [Train-Loss = 25.1] || [Validation-Loss = 5.308]
# Epoch 125/200: [Train-Loss = 24.835] || [Validation-Loss = 5.746]
# Epoch 126/200: [Train-Loss = 25.456] || [Validation-Loss = 5.795]
# Epoch 127/200: [Train-Loss = 28.222] || [Validation-Loss = 5.44]
# Epoch 128/200: [Train-Loss = 27.411] || [Validation-Loss = 6.942]
# Epoch 129/200: [Train-Loss = 26.749] || [Validation-Loss = 5.929]
# Epoch 130/200: [Train-Loss = 26.529] || [Validation-Loss = 8.119]
# Epoch 131/200: [Train-Loss = 26.186] || [Validation-Loss = 7.096]
# Epoch 132/200: [Train-Loss = 30.201] || [Validation-Loss = 4.773]
# Epoch 133/200: [Train-Loss = 25.509] || [Validation-Loss = 7.257]
# Epoch 134/200: [Train-Loss = 25.523] || [Validation-Loss = 5.034]
# Epoch 135/200: [Train-Loss = 24.21] || [Validation-Loss = 4.759]
# Epoch 136/200: [Train-Loss = 23.831] || [Validation-Loss = 6.436]
# Epoch 137/200: [Train-Loss = 23.951] || [Validation-Loss = 9.863]
# Epoch 138/200: [Train-Loss = 25.243] || [Validation-Loss = 6.438]
# Epoch 139/200: [Train-Loss = 24.955] || [Validation-Loss = 5.233]
# Epoch 140/200: [Train-Loss = 27.084] || [Validation-Loss = 8.794]
# Epoch 141/200: [Train-Loss = 25.855] || [Validation-Loss = 5.706]
# Epoch 142/200: [Train-Loss = 24.087] || [Validation-Loss = 7.14]
# Epoch 143/200: [Train-Loss = 22.323] || [Validation-Loss = 5.513]
# Epoch 144/200: [Train-Loss = 22.767] || [Validation-Loss = 5.285]
# Epoch 145/200: [Train-Loss = 23.466] || [Validation-Loss = 5.447]
# Epoch 146/200: [Train-Loss = 26.031] || [Validation-Loss = 7.719]
# Epoch 147/200: [Train-Loss = 27.932] || [Validation-Loss = 5.576]
# Epoch 148/200: [Train-Loss = 24.12] || [Validation-Loss = 4.707]
# Epoch 149/200: [Train-Loss = 23.413] || [Validation-Loss = 6.17]
# Epoch 150/200: [Train-Loss = 25.827] || [Validation-Loss = 6.741]
# Epoch 151/200: [Train-Loss = 23.548] || [Validation-Loss = 8.608]
# Epoch 152/200: [Train-Loss = 22.557] || [Validation-Loss = 5.726]
# Epoch 153/200: [Train-Loss = 22.605] || [Validation-Loss = 7.834]
# Epoch 154/200: [Train-Loss = 21.545] || [Validation-Loss = 6.456]
# Epoch 155/200: [Train-Loss = 22.589] || [Validation-Loss = 6.586]
# Epoch 156/200: [Train-Loss = 21.372] || [Validation-Loss = 5.06]
# Epoch 157/200: [Train-Loss = 20.717] || [Validation-Loss = 7.09]
# Epoch 158/200: [Train-Loss = 22.562] || [Validation-Loss = 7.26]
# Epoch 159/200: [Train-Loss = 21.666] || [Validation-Loss = 6.738]
# Epoch 160/200: [Train-Loss = 22.367] || [Validation-Loss = 6.63]
# Epoch 161/200: [Train-Loss = 22.126] || [Validation-Loss = 5.977]
# Epoch 162/200: [Train-Loss = 21.624] || [Validation-Loss = 7.972]
# Epoch 163/200: [Train-Loss = 22.878] || [Validation-Loss = 6.046]
# Epoch 164/200: [Train-Loss = 21.706] || [Validation-Loss = 9.165]
# Epoch 165/200: [Train-Loss = 24.478] || [Validation-Loss = 5.49]
# Epoch 166/200: [Train-Loss = 20.199] || [Validation-Loss = 6.522]
# Epoch 167/200: [Train-Loss = 20.919] || [Validation-Loss = 5.624]
# Epoch 168/200: [Train-Loss = 22.231] || [Validation-Loss = 5.973]
# Epoch 169/200: [Train-Loss = 21.541] || [Validation-Loss = 5.822]
# Epoch 170/200: [Train-Loss = 22.273] || [Validation-Loss = 5.839]
# Epoch 171/200: [Train-Loss = 20.678] || [Validation-Loss = 8.349]
# Epoch 172/200: [Train-Loss = 20.598] || [Validation-Loss = 5.854]
# Epoch 173/200: [Train-Loss = 17.751] || [Validation-Loss = 8.615]
# Epoch 174/200: [Train-Loss = 19.371] || [Validation-Loss = 7.058]
# Epoch 175/200: [Train-Loss = 23.333] || [Validation-Loss = 5.829]
# Epoch 176/200: [Train-Loss = 20.234] || [Validation-Loss = 7.09]
# Epoch 177/200: [Train-Loss = 19.49] || [Validation-Loss = 9.261]
# Epoch 178/200: [Train-Loss = 20.289] || [Validation-Loss = 8.565]
# Epoch 179/200: [Train-Loss = 18.825] || [Validation-Loss = 8.418]
# Epoch 180/200: [Train-Loss = 20.201] || [Validation-Loss = 7.519]
# Epoch 181/200: [Train-Loss = 19.786] || [Validation-Loss = 6.164]
# Epoch 182/200: [Train-Loss = 20.042] || [Validation-Loss = 5.342]
# Epoch 183/200: [Train-Loss = 19.56] || [Validation-Loss = 5.588]
# Epoch 184/200: [Train-Loss = 19.852] || [Validation-Loss = 6.346]
# Epoch 185/200: [Train-Loss = 18.95] || [Validation-Loss = 6.261]
# Epoch 186/200: [Train-Loss = 20.153] || [Validation-Loss = 5.839]
# Epoch 187/200: [Train-Loss = 19.798] || [Validation-Loss = 7.721]
# Epoch 188/200: [Train-Loss = 18.675] || [Validation-Loss = 5.992]
# Epoch 189/200: [Train-Loss = 16.364] || [Validation-Loss = 6.466]
# Epoch 190/200: [Train-Loss = 18.321] || [Validation-Loss = 5.671]
# Epoch 191/200: [Train-Loss = 18.734] || [Validation-Loss = 7.437]
# Epoch 192/200: [Train-Loss = 20.058] || [Validation-Loss = 7.59]
# Epoch 193/200: [Train-Loss = 18.787] || [Validation-Loss = 20.987]
# Epoch 194/200: [Train-Loss = 18.61] || [Validation-Loss = 8.244]
# Epoch 195/200: [Train-Loss = 18.038] || [Validation-Loss = 6.717]
# Epoch 196/200: [Train-Loss = 20.451] || [Validation-Loss = 6.166]
# Epoch 197/200: [Train-Loss = 19.266] || [Validation-Loss = 5.956]
# Epoch 198/200: [Train-Loss = 17.376] || [Validation-Loss = 5.437]
# Epoch 199/200: [Train-Loss = 18.462] || [Validation-Loss = 6.292]
# Epoch 200/200: [Train-Loss = 17.063] || [Validation-Loss = 6.723]

# %%
y_true, y_pred, y_prob, y_images = resnet101.predict(testloader)
# Out:
# Calculate Predictions:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
EvaluationPlots.plot_train_val_loss(resnet101.train_loss,resnet101.val_loss,)

# %%
EvaluationPlots.metric_evaluation(y_true, y_pred,list(label_dict))

# %%
EvaluationPlots.plot_pred(y_true, y_pred, y_prob, y_images,4, incorrect = False,label_dict=label_dict)
# Out:
# G:\Semester 6\Challenge X\manhole-cover-classification\model\..\utils\plots\plots.py:176: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2318.)
#   ax.imshow(image.T)

# %%
EvaluationPlots.plot_pred(y_true, y_pred, y_prob, y_images,9, incorrect = True,label_dict=label_dict)

# %%
torch.save(resnet101, 'model.pth')

# %%
model = torch.load('model_resnet101.pth')
model

# %%
df
# Out:
#               image    set                            label     sub
# 0     100184900.png  train                Rost/Strassenrost  square
# 1     100034700.png  train                Rost/Strassenrost  square
# 2     100003200.png  train   Vollguss/Handgriff geschlossen   round
# 3     100004000.png  train   Gussbeton/Pickelloch belueftet   round
# 4     100125300.png  train   Vollguss/Handgriff geschlossen   round
# ...             ...    ...                              ...     ...
# 2065  100136300.png    val                Rost/Strassenrost  square
# 2066  100018200.png    val  Vollguss/Pickelloch geschlossen   round
# 2067  100009400.png    val   Vollguss/Handgriff geschlossen   round
# 2068  100122000.png    val                Rost/Einlauf rund   round
# 2069  100018100.png    val   Vollguss/Handgriff geschlossen   round
#
# [2070 rows x 4 columns]

# %%
for i in range(10):
    imgg = "../data/images_transformed/"+list(df.sample()["image"])[0]
    image = PIL.Image.open(imgg)
    image = my_test_transforms(image)
    image = image.reshape(1, 3, 224, 224)
    image = image.to(device)
    image.requires_grad_()
    output = model.model(image)
    # Catch the output
    output_idx = output.argmax()
    output_max = output[0, output_idx]

    # Do backpropagation to get the derivative of the output based on the image
    output_max.backward()

    # Retireve the saliency map and also pick the maximum value from channels on each pixel.
    # In this case, we look at dim=1. Recall the shape (batch_size, channel, width, height)
    saliency, _ = torch.max(image.grad.data.abs(), dim=1) 
    saliency = saliency.reshape(224, 224)

    # Reshape the image
    image = image.reshape(-1, 224, 224)

    # Visualize the image and the saliency map
    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(image.cpu().detach().numpy().transpose(1, 2, 0))
    ax[0].axis('off')
    ax[1].imshow(saliency.cpu(), cmap='hot')
    ax[1].axis('off')
    plt.tight_layout()
    fig.suptitle('label:'+list(df.sample()["label"])[0])
    plt.show()
